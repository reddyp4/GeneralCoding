# %% [markdown]
# **Assignment Gradient Descent **
#
# Imagine a building that uses a complex energy consumption system to regulate its temperature and lighting. The energy consumption system has several variables that affect its efficiency, such as the temperature setpoint, lighting levels, and ventilation rates. The function J(x) = x2 - 4x + 3 can be seen as a simplified model of the efficiency of the energy consumption system, where x represents one of the variables that affect the system's efficiency.
#
# For example, x could represent the temperature setpoint. By adjusting the value of x using Gradient Descent, the building managers can find the optimal temperature setpoint that would minimize the value of the cost function and result in the most efficient energy consumption system. This optimization would result in lower energy consumption costs and reduced carbon emissions, while still maintaining a comfortable environment for the building occupants. You will be implementing the Gradient Descent algorithm to find the minimum of the quadratic cost function.
#
# **Background**
#
# Gradient Descent is an iterative optimization algorithm that is commonly used to minimize a cost function by adjusting the parameters of a model. The algorithm works by iteratively updating the parameters in the opposite direction of the gradient of the cost function. The learning rate determines the size of the step taken in the opposite direction of the gradient.
#
# **Tasks**

# %%
# Q1) Implement the following function:

def gradient_descent(J, x, alpha, num_iters):

    """

    Performs Gradient Descent to optimize the cost function J(theta).
    J(x) = x2 - 4x + 3



    Arguments:

    x -- initial parameter value (scalar)

    alpha -- learning rate (scalar)

    num_iters -- the number of iterations to run Gradient Descent (scalar)



    Returns:

    x_final -- optimized parameter value

    J_history -- vector of cost function values for each iteration (num_iters x 1)

    """



    # Your code here
    x_final = x
    J_history = []
    for i in range(num_iters):
      J_history.append(2*x_final-4*x_final+3)
      grad = 2*x_final - 4
      x_final += - grad * alpha


    return x_final, J_history

# %%
#Plot the cost function
import numpy as np
import matplotlib.pyplot as plt

#values of x
x = np.linspace(-8,12,1000)

def J_cost(x):
  return (x**2) - 4*x + 3

def dJ(x):
  return (2*x-4)

#plot cost vs x
y = J_cost(x)

#Plot
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# **Q2)**
#
# Implementing different convergence criteria: Convergence criteria for gradient descent refers to the condition under which the algorithm is considered to have found an acceptable solution. There are several common convergence criteria for gradient descent, including,
#
#
#
# **a) **
#
# Maximum number of iterations: In the previous code, you have limited the number of iterations that the algorithm will perform. The algorithm stops after a fixed number of iterations, regardless of the change in the objective function.
#
#
#
# **b) **
#
# Minimum change in objective function: The algorithm can also be stopped when the change in the objective function between consecutive iterations falls below a certain threshold (called tolerance), indicating that the algorithm has converged to a preferred minimum. In other words, we need some minimum improvement in the objective function value between consecutive iterations that is considered significant enough to continue the optimization process. It is often specified as a small positive number, such as 1e-3 or 1e-6.
#
#
#
# Choosing an appropriate tolerance value depends on the problem being solved and the computational resources available. A smaller tolerance value can lead to a more accurate solution but may require more iterations to achieve convergence, while a larger tolerance value can result in faster convergence but may not produce as accurate a solution. It is important to balance accuracy with computational efficiency when selecting a tolerance value for gradient descent.
#
#
#
# Implement the following function:
#
# def gradient_descent(J, dJ, x, alpha, tol, max_iters):
#
#     """
#
#     Performs gradient descent to minimize the objective function J.
#
#     Arguments:
#
#     J -- objective function to be minimized
#
#     dJ -- gradient of the objective function
#
#     x -- initial guess for the solution
#
#     alpha -- learning rate
#
#     tol -- tolerance for convergence
#
#     max_iters -- maximum number of iterations to perform
#
#
#
#     Returns:
#
#     x -- solution to the optimization problem
#
#     """
#
#     iter = 0
#
# # Your code here
#
#         #Steps:
#
#   #1) compute the gradient and update x
#
#   #2) compute the improvement in the objective function
#
#         #3) update x and iteration counter
#
#     return x, J_history
#
#
#
# Document the impact on the final solution for different tolerance values.

# %%
'''
a) Maximum number of iterations: In the previous code, you have limited the number of iterations that the algorithm will perform.
The algorithm stops after a fixed number of iterations, regardless of the change in the objective function.

'''
def gradient_descent_conv(J,dJ,x,alpha,tol,num_iters):
  x_final = x
  i=0
  while( ((x_final-x)**2 < tol**2) and i<num_iters ):
    J_history.append(2*x_final-4*x_final+3)
    x_final = x
    grad = 2*x_final - 4
    x_final += -grad*alpha
    i+=1

  return x_final, J_history

# %% [markdown]
# **Q3) **
#
# Comparison of performance for different initializations
#
# The initial values of the parameter (x) can have a significant impact on the performance of the algorithm. If the initial value is too large or too small, the algorithm may converge to a suboptimal solution in the given iterations.
#
#
#
# Initialize the parameters with different values to study the impact of different initializations on the performance of Gradient Descent. You can use the above code to compare the performance of the different initializations in terms of convergence time.
#
#
#
# Select the initialization that gives the best result and use it for further experiments.

# %%
import numpy as np
import matplotlib.pyplot as plt

#Initial guesses
J = []
#Initial guess
x1 = -15
#Learning rate
alpha1 = 0.01
#Number of iterations
num_iters1 = 1000

[x_result, J_result] = gradient_descent(J,x1,alpha1,num_iters1)

plt.plot(J_result)
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.title("Trial1")
plt.show()

# %%
#Initial guess
x2 = 25
#Learning rate
alpha1 = 0.01
#Number of iterations
num_iters1 = 1000

[x_result, J_result2] = gradient_descent(J,x2,alpha1,num_iters1)

plt.plot(J_result2)
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.title("Trial1")
plt.show()

# %% [markdown]
# **Q4) **
#
# Impact of the learning rate [Optional]
#
# The learning rate is a crucial hyperparameter in Gradient Descent that determines the size of the step taken in the opposite direction of the gradient. If the learning rate is too small, the algorithm will take a long time to converge to the minimum. If the learning rate is too large, the algorithm may overshoot the minimum and diverge. Experiment with different learning rates and plot the cost function values over the iterations to visualize the convergence.

# %%
#Change the learning rate = alpha and check the convergence
alpha2 = 0.1

[x_result, J_result3] = gradient_descent(J,x2,alpha2,num_iters1)

alpha3 = 0.5
[x_result, J_result4] = gradient_descent(J,x2,alpha3,num_iters1)

plt.plot(J_result2)
plt.plot(J_result3)
plt.plot(J_result4)
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.title("Trial1")
plt.legend(["alpha=0.01","alpha=0.1","alpha=1"])
plt.show()

# %%
#Add cost function to visualize the convergence for alpha2
plt.plot(x,y)
plt.plot(J_result)  #Needs modification to see how x changes!

# %% [markdown]
# **Q5) **
#
# Impact of learning strategies [Optional]
#
# So far, you had a ‘constant’ learning rate (alpha). Two popular learning strategies for adapting the learning rate during training are invscaling and adaptive learning rate. You will be implementing these two strategies
#
#
#
# The invscaling strategy decreases the learning rate over time according to a schedule. A common schedule is to divide the learning rate by the square root of the iteration number:
# alpha = alpha0 / sqrt(t)
#
#
#
# where alpha0 is the initial learning rate and t is the iteration number. This strategy is based on the intuition that as the algorithm approaches the minimum, the step size should become smaller to avoid overshooting it.

# %%
#New function with invscaling stragegy
import math

def gradient_descent_invscaling(J, dJ, x, alpha, tol,tol2, max_iters):
  # Gradient descent:
  # J: objective function to be minimized
  # dJ: gradient
  # x: initial guess
  # alpha: Initial alpha
  # tol: tolerance
  # max_iters: maximum iterations
  x_final = 0
  i = 1
  Alpha_result=[]
  J_result=[]
  print(x_final,x,tol)
  while ( (x_final-x)**2 > tol**2 ): #(i < max_iters) &
    x_final = x
    J_result.append(J(x_final))
    Alpha_result.append(alpha)
    grad = dJ(x_final)
    x_final += -grad*alpha
    if((x_final-x)**2 < tol2):
      alpha = alpha/math.sqrt(i)
    i+=1
    print("Iteration:",i,",x_final:",x_final,",x:",x,"Alpha:",alpha,",grad:",grad)

  return x_final,J_result

# %%
#Change the learning rate = alpha and check the convergence
x2 = -25
alpha5 = 0.1
tol1 = 0.00000001
num_iter1 = 10

[x_result, J_result5] = gradient_descent_invscaling(J_cost,dJ,x2,alpha5,tol1,0.1,num_iters1)

plt.plot(J_result5)
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.title("Invscaling")
plt.show()

print("Final x:",x_result)
# Out:
# 0 -25 1e-08
# Iteration: 2 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 3 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 4 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 5 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 6 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 7 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 8 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 9 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 10 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 11 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 12 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 13 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 14 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 15 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 16 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 17 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 18 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 19 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 20 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 21 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 22 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 23 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 24 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 25 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 26 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 27 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 28 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 29 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 30 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 31 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 32 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 33 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 34 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 35 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 36 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 37 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 38 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 39 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 40 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 41 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 42 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 43 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 44 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 45 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 46 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 47 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 48 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 49 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 50 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 51 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 52 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 53 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 54 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 55 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 56 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 57 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 58 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 59 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 60 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 61 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 62 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 63 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 64 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 65 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 66 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 67 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 68 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 69 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 70 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 71 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 72 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 73 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 74 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 75 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 76 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 77 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 78 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 79 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 80 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 81 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 82 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 83 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 84 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 85 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 86 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 87 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 88 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 89 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 90 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 91 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 92 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 93 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 94 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 95 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 96 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 97 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 98 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 99 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 100 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 101 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 102 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 103 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 104 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 105 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 106 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 107 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 108 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 109 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 110 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 111 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 112 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 113 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 114 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 115 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 116 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 117 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 118 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 119 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 120 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 121 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 122 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 123 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 124 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 125 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 126 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 127 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 128 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 129 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 130 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 131 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 132 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 133 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 134 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 135 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 136 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 137 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 138 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 139 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 140 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 141 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 142 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 143 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 144 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 145 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 146 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 147 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 148 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 149 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 150 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 151 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 152 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 153 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 154 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 155 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 156 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 157 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 158 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 159 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 160 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 161 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 162 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 163 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 164 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 165 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 166 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 167 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 168 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 169 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 170 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 171 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 172 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 173 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 174 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 175 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 176 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 177 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 178 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 179 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 180 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 181 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 182 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 183 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 184 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 185 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 186 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 187 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 188 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 189 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 190 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 191 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 192 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 193 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 194 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 195 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 196 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 197 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 198 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 199 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 200 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 201 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 202 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 203 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 204 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 205 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 206 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 207 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 208 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 209 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 210 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 211 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 212 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 213 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 214 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 215 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 216 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 217 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 218 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 219 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 220 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 221 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 222 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 223 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 224 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 225 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 226 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 227 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 228 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 229 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 230 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 231 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 232 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 233 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 234 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 235 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 236 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 237 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 238 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 239 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 240 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 241 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 242 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 243 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 244 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 245 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 246 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 247 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 248 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 249 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 250 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 251 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 252 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 253 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 254 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 255 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 256 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 257 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 258 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 259 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 260 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 261 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 262 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 263 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 264 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 265 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 266 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 267 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 268 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 269 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 270 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 271 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 272 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 273 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 274 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 275 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 276 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 277 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 278 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 279 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 280 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 281 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 282 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 283 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 284 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 285 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 286 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 287 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 288 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 289 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 290 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 291 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 292 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 293 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 294 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 295 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 296 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 297 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 298 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 299 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 300 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 301 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 302 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 303 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 304 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 305 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 306 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 307 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 308 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 309 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 310 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 311 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 312 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 313 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 314 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 315 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 316 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 317 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 318 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 319 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 320 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 321 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 322 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 323 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 324 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 325 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 326 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 327 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 328 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 329 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 330 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 331 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 332 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 333 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 334 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 335 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 336 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 337 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 338 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 339 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 340 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 341 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 342 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 343 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 344 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 345 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 346 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 347 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 348 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 349 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 350 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 351 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 352 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 353 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 354 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 355 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 356 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 357 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 358 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 359 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 360 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 361 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 362 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 363 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 364 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 365 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 366 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 367 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 368 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 369 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 370 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 371 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 372 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 373 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 374 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 375 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 376 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 377 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 378 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 379 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 380 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 381 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 382 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 383 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 384 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 385 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 386 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 387 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 388 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 389 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 390 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 391 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 392 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 393 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 394 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 395 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 396 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 397 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 398 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 399 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 400 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 401 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 402 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 403 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 404 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 405 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 406 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 407 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 408 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 409 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 410 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 411 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 412 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 413 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 414 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 415 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 416 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 417 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 418 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 419 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 420 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 421 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 422 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 423 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 424 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 425 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 426 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 427 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 428 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 429 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 430 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 431 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 432 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 433 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 434 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 435 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 436 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 437 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 438 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 439 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 440 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 441 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 442 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 443 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 444 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 445 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 446 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 447 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 448 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 449 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 450 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 451 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 452 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 453 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 454 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 455 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 456 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 457 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 458 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 459 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 460 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 461 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 462 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 463 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 464 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 465 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 466 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 467 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 468 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 469 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 470 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 471 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 472 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 473 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 474 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 475 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 476 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 477 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 478 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 479 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 480 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 481 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 482 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 483 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 484 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 485 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 486 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 487 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 488 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 489 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 490 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 491 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 492 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 493 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 494 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 495 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 496 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 497 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 498 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 499 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 500 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 501 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 502 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 503 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 504 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 505 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 506 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 507 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 508 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 509 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 510 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 511 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 512 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 513 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 514 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 515 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 516 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 517 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 518 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 519 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 520 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 521 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 522 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 523 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 524 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 525 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 526 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 527 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 528 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 529 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 530 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 531 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 532 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 533 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 534 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 535 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 536 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 537 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 538 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 539 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 540 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 541 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 542 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 543 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 544 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 545 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 546 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 547 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 548 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 549 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 550 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 551 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 552 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 553 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 554 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 555 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 556 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 557 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 558 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 559 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 560 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 561 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 562 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 563 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 564 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 565 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 566 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 567 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 568 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 569 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 570 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 571 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 572 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 573 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 574 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 575 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 576 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 577 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 578 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 579 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 580 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 581 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 582 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 583 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 584 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 585 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 586 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 587 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 588 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 589 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 590 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 591 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 592 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 593 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 594 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 595 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 596 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 597 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 598 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 599 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 600 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 601 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 602 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 603 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 604 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 605 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 606 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 607 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 608 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 609 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 610 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 611 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 612 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 613 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 614 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 615 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 616 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 617 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 618 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 619 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 620 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 621 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 622 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 623 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 624 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 625 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 626 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 627 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 628 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 629 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 630 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 631 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 632 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 633 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 634 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 635 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 636 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 637 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 638 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 639 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 640 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 641 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 642 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 643 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 644 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 645 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 646 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 647 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 648 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 649 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 650 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 651 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 652 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 653 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 654 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 655 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 656 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 657 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 658 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 659 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 660 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 661 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 662 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 663 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 664 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 665 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 666 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 667 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 668 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 669 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 670 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 671 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 672 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 673 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 674 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 675 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 676 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 677 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 678 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 679 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 680 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 681 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 682 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 683 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 684 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 685 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 686 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 687 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 688 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 689 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 690 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 691 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 692 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 693 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 694 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 695 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 696 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 697 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 698 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 699 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 700 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 701 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 702 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 703 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 704 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 705 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 706 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 707 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 708 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 709 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 710 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 711 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 712 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 713 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 714 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 715 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 716 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 717 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 718 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 719 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 720 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 721 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 722 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 723 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 724 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 725 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 726 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 727 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 728 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 729 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 730 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 731 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 732 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 733 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 734 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 735 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 736 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 737 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 738 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 739 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 740 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 741 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 742 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 743 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 744 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 745 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 746 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 747 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 748 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 749 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 750 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 751 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 752 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 753 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 754 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 755 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 756 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 757 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 758 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 759 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 760 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 761 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 762 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 763 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 764 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 765 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 766 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 767 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 768 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 769 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 770 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 771 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 772 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 773 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 774 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 775 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 776 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 777 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 778 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 779 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 780 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 781 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 782 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 783 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 784 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 785 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 786 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 787 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 788 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 789 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# ...
# Iteration: 1824 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1825 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1826 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1827 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1828 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1829 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1830 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1831 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1832 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1833 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1834 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1835 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1836 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1837 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1838 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1839 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1840 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1841 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1842 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1843 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1844 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1845 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1846 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1847 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1848 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1849 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1850 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1851 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1852 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1853 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1854 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1855 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1856 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1857 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1858 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1859 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1860 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1861 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1862 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1863 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1864 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1865 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1866 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1867 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1868 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1869 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1870 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1871 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1872 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1873 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1874 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1875 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1876 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1877 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1878 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1879 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1880 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1881 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1882 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1883 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1884 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1885 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1886 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1887 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1888 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1889 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1890 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1891 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1892 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1893 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1894 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1895 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1896 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1897 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1898 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1899 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1900 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1901 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1902 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1903 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1904 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1905 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1906 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1907 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1908 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1909 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1910 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1911 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1912 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1913 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1914 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1915 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1916 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1917 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1918 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1919 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1920 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1921 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1922 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1923 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1924 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1925 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1926 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1927 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1928 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1929 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1930 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1931 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1932 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1933 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1934 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1935 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1936 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1937 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1938 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1939 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1940 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1941 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1942 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1943 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1944 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1945 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1946 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1947 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1948 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1949 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1950 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1951 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1952 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1953 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1954 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1955 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1956 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1957 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1958 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1959 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1960 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1961 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1962 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1963 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1964 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1965 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1966 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1967 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1968 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1969 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1970 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1971 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1972 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1973 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1974 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1975 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1976 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1977 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1978 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1979 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1980 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1981 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1982 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1983 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1984 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1985 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1986 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1987 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1988 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1989 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1990 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1991 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1992 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1993 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1994 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1995 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1996 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1997 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1998 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 1999 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2000 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2001 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2002 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2003 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2004 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2005 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2006 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2007 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2008 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2009 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2010 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2011 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2012 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2013 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2014 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2015 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2016 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2017 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2018 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2019 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2020 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2021 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2022 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2023 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2024 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2025 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2026 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2027 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2028 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2029 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2030 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2031 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2032 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2033 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2034 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2035 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2036 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2037 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2038 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2039 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2040 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2041 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2042 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2043 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2044 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2045 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2046 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2047 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2048 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2049 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2050 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2051 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2052 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2053 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration: 2054 ,x_final: -19.6 ,x: -25 Alpha: 0.1 ,grad: -54
# Iteration:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-3fea10fe42d1> in <cell line: 7>()
#       5 num_iter1 = 10
#       6
# ----> 7 [x_result, J_result5] = gradient_descent_invscaling(J_cost,dJ,x2,alpha5,tol1,0.1,num_iters1)
#       8
#       9 plt.plot(J_result5)
#
# <ipython-input-74-8c4e6b9569e6> in gradient_descent_invscaling(J, dJ, x, alpha, tol, tol2, max_iters)
#      24       alpha = alpha/math.sqrt(i)
#      25     i+=1
# ---> 26     print("Iteration:",i,",x_final:",x_final,",x:",x,"Alpha:",alpha,",grad:",grad)
#      27
#      28   return x_final,J_result
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.10/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     541         ...
#     542
# --> 543     def send(
#     544         self,
#     545         data: Any,
#
# KeyboardInterrupt:

# %% [markdown]
# The adaptive learning rate strategy is a form of learning rate annealing or decay, where the learning rate is reduced to prevent overshooting and oscillations. One common approach is to decrease the learning rate by a factor, such as dividing it by 5 or 10 if overshooting occurs. The change in the sign of the gradient will indicate overshooting during optimization.
#
#
# The task is to visualize the optimization process with different learning rates and learning strategies for the given objective function. Plot the function J(x) as a function of x, with the path taken by gradient descent, superimposed, using libraries such as Matplotlib.
